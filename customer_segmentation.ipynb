# %% [markdown]
# # Описание проекта

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования.
#
# Нужно разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# # Как решать задачу

# %% [markdown]
# Руководитель отдела сформировал подход к решению этой задачи:
#
# 1. Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
# 2. Нужно собрать данные по клиентам по следующим группам:
#     - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
#     - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#     - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#     - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.

# %% [markdown]
# Представим группы признаков (вместе с целевым) в виде диаграммы — такую визуализацию ещё называют диаграммой Исикавы.
#
# На диаграмме входные признаки объединены в четыре группы:
# - коммуникация с клиентом,
# - продуктовое поведение,
# - поведение на сайте,
# - финансовое поведение.
#
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.

# %% [markdown]
# # Описание данных

# %% [markdown]
# Данные для работы находятся в нескольких таблицах.
#
# - market_file.csv таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#     - id — номер покупателя в корпоративной базе данных.
#     - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#     - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
#     - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#     - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#     - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
#     - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#     - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#     - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
#     - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#     - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
#     - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
#     - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
#
# - market_money.csv таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#     - id — номер покупателя в корпоративной базе данных.
#     - Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#     - Выручка — сумма выручки за период.
#
#
# - market_time.csv таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#     - id — номер покупателя в корпоративной базе данных.
#     - Период — название периода, во время которого зафиксировано общее время.
#     - минут — значение времени, проведённого на сайте, в минутах.
#
#
# - money.csv таблица с данными о среднемесячной прибыли продавца за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#     - id — номер покупателя в корпоративной базе данных.
#     - Прибыль — значение прибыли.

# %% [markdown]
# Решать задачу нужно в два этапа:
# 1. Разработать модель, которая предскажет вероятность снижения покупательской активности.
# 2. Выделить сегмент покупателей, проанализировать его и предложить, как увеличить его покупательскую активность. Использовать данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию можно проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов:
#
# - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# - Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# - Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# ## Загрузка данных

# %%
# !pip install phik -q

# %%
# !pip install shap -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import datetime
import warnings
import scipy.stats as st
import random
import shap

from phik import phik_matrix

from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, OrdinalEncoder, LabelEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (r2_score, mean_absolute_error, mean_squared_error,
                             accuracy_score, recall_score, precision_score,
                             confusion_matrix, precision_recall_curve,
                             f1_score, fbeta_score, roc_curve, RocCurveDisplay, roc_auc_score)

from sklearn.inspection import permutation_importance
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
market_file = pd.read_csv('/datasets/market_file.csv')
market_file
# Out:
#           id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась   стандартт                нет
# 3     215351                 Снизилась   стандартт                 да
# 4     215352                 Снизилась   стандартт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# 0                    3.4                     5           121
# ...

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_money = pd.read_csv('/datasets/market_money.csv')
market_money
# Out:
#           id               Период  Выручка
# 0     215348  препредыдущий_месяц      0.0
# 1     215348        текущий_месяц   3293.1
# 2     215348     предыдущий_месяц      0.0
# 3     215349  препредыдущий_месяц   4472.0
# 4     215349        текущий_месяц   4971.6
# ...      ...                  ...      ...
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#
# [3900 rows x 3 columns]

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_time = pd.read_csv('/datasets/market_time.csv')
market_time
# Out:
#           id            Период  минут
# 0     215348     текущий_месяц     14
# 1     215348  предыдцщий_месяц     13
# 2     215349     текущий_месяц     10
# 3     215349  предыдцщий_месяц     12
# 4     215350     текущий_месяц     13
# ...      ...               ...    ...
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдцщий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдцщий_месяц     15
#
# [2600 rows x 3 columns]

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')
money
# Out:
#           id  Прибыль
# 0     215348     0.98
# 1     215349     4.16
# 2     215350     3.13
# 3     215351     4.87
# 4     215352     4.21
# ...      ...      ...
# 1295  216643     4.44
# 1296  216644     6.11
# 1297  216645     3.29
# 1298  216646     4.03
# 1299  216647     3.28
#
# [1300 rows x 2 columns]

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# <font color='Black'><b>Вывод после загрузки и изучения данных:  </b></font><br>
#
# - Не все столбцы выполнены в «змеином_регистре».
# - В данных нет пропусков.
# - Данные в таблицах соответствуют описанию.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Приведем в порядок название столбцов:

# %%
market_file.columns = market_file.columns.str.lower().str.replace(' ', '_').str.replace(',', '_').str.replace('__', '_')
market_file.columns
# Out:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')

# %%
market_money.columns = market_money.columns.str.lower().str.replace(' ', '_').str.replace(',', '_').str.replace('__', '_')
market_money.columns
# Out:
# Index(['id', 'период', 'выручка'], dtype='object')

# %%
market_time.columns = market_time.columns.str.lower() # названия столбцов приведем к нижнему регистру
market_time.columns
# Out:
# Index(['id', 'период', 'минут'], dtype='object')

# %%
money.columns = money.columns.str.lower().str.replace(' ', '_').str.replace(',', '_').str.replace('__', '_')
money.columns
# Out:
# Index(['id', 'прибыль'], dtype='object')

# %% [markdown]
# Устраним опечатки в данных:

# %%
market_time['период'] = (market_time['период'].replace('предыдцщий_месяц', 'предыдущий_месяц', regex=True)) 
market_time['период'].unique()
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %%
market_file['тип_сервиса'] = market_file['тип_сервиса'].replace('стандартт', 'стандарт', regex=True)
market_file['тип_сервиса'].unique()
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %% [markdown]
# Проверим данные на наличие дубликатов:

# %%
market_file.duplicated().sum()
# Out:
# 0

# %%
market_money.duplicated().sum()
# Out:
# 0

# %%
market_time.duplicated().sum()
# Out:
# 0

# %%
money.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <font color='Black'><b>Вывод после предобработки данных:  </b></font><br>
#
# - Привели названия столбцов к единому стилю.
# - Устранили опечатки, проверили данные на наличие дубликатов.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Количественные признаки market_file:

# %%
market_file.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась    стандарт                нет
# 3  215351                 Снизилась    стандарт                 да
# 4  215352                 Снизилась    стандарт                нет
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
market_file['маркет_актив_6_мес'].describe()
# Out:
# count    1300.000000
# mean        4.253769
# std         1.014814
# min         0.900000
# 25%         3.700000
# 50%         4.200000
# 75%         4.900000
# max         6.600000
# Name: маркет_актив_6_мес, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='маркет_актив_6_мес',data=market_file)
plt.title('Диаграмма размаха для среднемесячного значения маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев', fontsize=15)
plt.xlabel('Число рассылок, звонков, показов рекламы и прочего приходилось на клиента')
plt.show()

# %%
market_file['маркет_актив_6_мес'].plot(kind = 'hist', bins = 30, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения среднемесячного значения маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев', fontsize=15)
plt.xlabel('Число рассылок, звонков, показов рекламы и прочего приходилось на клиента')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
def chart_hist(df, col, target):
    sns.set()
    f, axes = plt.subplots(1, 2, figsize=(14, 6))
    axes[0].set_title(f'Гистограмма для {col}', fontsize=10)
    axes[0].set_ylabel('Количество', fontsize=12)
    if target != None:
        sns.histplot(df, bins=25, kde=True, ax=axes[0], hue=target, x=col)
    else:
        sns.histplot(df, bins=25, kde=True,  ax=axes[0], x=col)
    axes[1].set_title(f'График ящик с усами для {col}', fontsize=10)
    sns.boxplot(data=df, ax=axes[1], y=col, color='white')
    axes[1].set_ylabel(col, fontsize=12)
    plt.show()

# %%
chart_hist(market_file, 'маркет_актив_6_мес', 'покупательская_активность')

# %%
market_file['маркет_актив_тек_мес'].describe()
# Out:
# count    1300.000000
# mean        4.011538
# std         0.696868
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64

# %%
market_file['маркет_актив_тек_мес'].unique()
# Out:
# array([5, 4, 3])

# %%
market_file['маркет_актив_тек_мес'].plot(kind = 'hist', bins = 3, figsize = (10, 8), grid = True, legend = True)
plt.title('Гистограмма распределения количества маркетинговых коммуникаций компании, которое приходилось на покупателя в текущем месяце', fontsize=15)
plt.xlabel('Число рассылок, звонков, показов рекламы и прочего, которое приходилось на клиента')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
market_file['длительность'].describe()
# Out:
# count    1300.000000
# mean      601.898462
# std       249.856289
# min       110.000000
# 25%       405.500000
# 50%       606.000000
# 75%       806.000000
# max      1079.000000
# Name: длительность, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='длительность',data=market_file)
plt.title('Диаграмма размаха времени с момента регистрации покупателя на сайте', fontsize=15)
plt.xlabel('Кол-во дней')
plt.show()

# %%
market_file['длительность'].plot(kind = 'hist', bins = 30, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения времени с момента регистрации покупателя на сайте', fontsize=15)
plt.xlabel('Кол-во дней')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
market_file['акционные_покупки'].describe()
# Out:
# count    1300.000000
# mean        0.319808
# std         0.249843
# min         0.000000
# 25%         0.170000
# 50%         0.240000
# 75%         0.300000
# max         0.990000
# Name: акционные_покупки, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='акционные_покупки',data=market_file)
plt.title('Диаграмма размаха среднемесячной доли покупок по акции от общего числа покупок за последние 6 месяцев', fontsize=15)
plt.xlabel('Доля покупок по акции от общего числа покупок')
plt.show()

# %%
market_file['акционные_покупки'].plot(kind = 'hist', bins = 30, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения среднемесячной доли покупок по акции от общего числа покупок за последние 6 месяцев', fontsize=15)
plt.xlabel('Доля покупок по акции от общего числа покупок')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
chart_hist(market_file, 'акционные_покупки', 'покупательская_активность')

# %%
market_file['средний_просмотр_категорий_за_визит'].describe()
# Out:
# count    1300.00000
# mean        3.27000
# std         1.35535
# min         1.00000
# 25%         2.00000
# 50%         3.00000
# 75%         4.00000
# max         6.00000
# Name: средний_просмотр_категорий_за_визит, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='средний_просмотр_категорий_за_визит',data=market_file)
plt.title('Диаграмма размаха среднего кол-ва просмотреных категорий покупателем за визит в течение последнего месяца', fontsize=15)
plt.xlabel('Среднее кол-во просмотреных категорий')
plt.show()

# %%
market_file['средний_просмотр_категорий_за_визит'].plot(kind = 'hist', bins = 6, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения среднего кол-ва просмотреных категорий покупателем за визит в течение последнего месяца', fontsize=15)
plt.xlabel('Среднее кол-во просмотреных категорий')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
market_file.pivot_table(index='средний_просмотр_категорий_за_визит',values='id',aggfunc='count') \
  .plot.pie(y='id', figsize=(10,7), autopct='%.2f')

plt.legend("", frameon=False)
plt.title('Среднее кол-во просмотреных категорий покупателем за визит в течение последнего месяца')
plt.show()

# %%
market_file['неоплаченные_продукты_штук_квартал'].describe()
# Out:
# count    1300.000000
# mean        2.840000
# std         1.971451
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='неоплаченные_продукты_штук_квартал',data=market_file)
plt.title('Диаграмма размаха кол-ва неоплаченных товаров в корзине за последние 3 месяца', fontsize=15)
plt.xlabel('Кол-во неоплаченных товаров')
plt.show()

# %%
market_file['неоплаченные_продукты_штук_квартал'].plot(kind = 'hist', bins = 10, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения кол-ва неоплаченных товаров в корзине за последние 3 месяца', fontsize=15)
plt.xlabel('Кол-во неоплаченных товаров')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
chart_hist(market_file, 'неоплаченные_продукты_штук_квартал', 'покупательская_активность')

# %%
market_file['ошибка_сервиса'].describe()
# Out:
# count    1300.000000
# mean        4.185385
# std         1.955298
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max         9.000000
# Name: ошибка_сервиса, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='ошибка_сервиса',data=market_file)
plt.title('Диаграмма размаха кол-ва сбоев, которые коснулись покупателя во время посещения сайта', fontsize=15)
plt.xlabel('Кол-во сбоев')
plt.show()

# %%
market_file['ошибка_сервиса'].plot(kind = 'hist', bins = 10, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения кол-ва сбоев, которые коснулись покупателя во время посещения сайта', fontsize=15)
plt.xlabel('Кол-во сбоев')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
market_file['страниц_за_визит'].describe()
# Out:
# count    1300.000000
# mean        8.176923
# std         3.978126
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        20.000000
# Name: страниц_за_визит, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='страниц_за_визит',data=market_file)
plt.title('Диаграмма размаха среднего количества страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца', fontsize=15)
plt.xlabel('Среднее количество страниц')
plt.show()

# %%
market_file['страниц_за_визит'].plot(kind = 'hist', bins = 20, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения среднего количества страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца', fontsize=15)
plt.xlabel('Среднее количество страниц')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %% [markdown]
# Категориальные признаки market_file:

# %%
# Создаем копию датасета, что бы не работать с исходным
mf = market_file.copy()

# Построение горизонтальной диаграммы
ax = mf['покупательская_активность'].value_counts(ascending=True).plot(
    kind='barh',
    figsize=(10, 2),
    title='Рассчитанный класс покупательской активности (целевой признак)' 
)

# Добавление значений рядом со столбцами
for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{width}',
                (width, p.get_y() + p.get_height() / 2.),
                ha='left', va='center',
                xytext=(5, 0),
                textcoords='offset points')

# Добавление меток осей
plt.xlabel('Количество клиентов')
plt.ylabel('Покупательская активность')

# Отображение графика
plt.show()

# %%
ax = mf['тип_сервиса'].value_counts(ascending=True).plot(
    kind='barh',
    figsize=(10, 2),
    title='Уровень сервиса' 
)

for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{width}',
                (width, p.get_y() + p.get_height() / 2.),
                ha='left', va='center',
                xytext=(5, 0),
                textcoords='offset points')

plt.xlabel('Количество клиентов')
plt.ylabel('Тип сервиса')
plt.show()

# %%
ax = mf['разрешить_сообщать'].value_counts(ascending=True).plot(
    kind='barh',
    figsize=(10, 2),
    title='Информация о том, можно ли присылать покупателю дополнительные предложения о товаре.' 
)

for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{width}',
                (width, p.get_y() + p.get_height() / 2.),
                ha='left', va='center',
                xytext=(5, 0),
                textcoords='offset points')

plt.xlabel('Количество клиентов')
plt.show()

# %%
ax = mf['популярная_категория'].value_counts(ascending=True).plot(
    kind='barh',
    figsize=(10, 2),
    title='Самая популярная категория товаров у покупателя за последние 6 месяцев.' 
)

for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{width}',
                (width, p.get_y() + p.get_height() / 2.),
                ha='left', va='center',
                xytext=(5, 0),
                textcoords='offset points')

plt.xlabel('Количество клиентов')
plt.show()

# %% [markdown]
# Количественные признаки market_money:

# %%
market_money.head()
# Out:
#        id               период  выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
market_money['выручка'].describe()
# Out:
# count      3900.000000
# mean       5025.696051
# std        1777.704104
# min           0.000000
# 25%        4590.150000
# 50%        4957.500000
# 75%        5363.000000
# max      106862.200000
# Name: выручка, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='выручка',data=market_money)
plt.title('Диаграмма размаха суммы выручки, которую получает магазин с покупателя за период взаимодействия с сайтом', fontsize=15)
plt.xlabel('Выручка')
plt.show()

# %% [markdown]
# Значение min = 0, max = 106862.2 - явные выбросы. Удалим строки

# %%
market_money = market_money[market_money['выручка']<100000]
market_money = market_money[market_money['выручка']>1]

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='выручка',data=market_money)
plt.title('Диаграмма размаха суммы выручки, которую получает магазин с покупателя за период взаимодействия с сайтом', fontsize=15)
plt.xlabel('Выручка')
plt.show()

# %%
market_money['выручка'].plot(kind = 'hist', bins = 20, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения суммы выручки, которую получает магазин с покупателя за период взаимодействия с сайтом', fontsize=15)
plt.xlabel('Выручка')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %%
market_money.pivot_table(index='период', values='выручка', aggfunc='sum') \
  .plot(y='выручка', figsize=(10,7), style='o-', alpha=0.3, grid=True)

plt.title('Выручка по месяцам')
plt.show()

# %% [markdown]
# Категориальные признаки market_money:

# %%
mm = market_money.copy()
ax = mm['период'].value_counts(ascending=True).plot(
    kind='barh',
    figsize=(10, 2),
    title='Период, во время которого зафиксирована выручка')

for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{width}',
                (width, p.get_y() + p.get_height() / 2.),
                ha='left', va='center',
                xytext=(5, 0),
                textcoords='offset points')

plt.xlabel('Количество клиентов')
plt.ylabel('Период')
plt.show()

# %% [markdown]
# Количественные признаки market_time:

# %%
market_time.head()
# Out:
#        id            период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдущий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдущий_месяц     12
# 4  215350     текущий_месяц     13

# %%
market_time['минут'].describe()
# Out:
# count    2600.000000
# mean       13.336154
# std         4.080198
# min         4.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        23.000000
# Name: минут, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='минут',data=market_time)
plt.title('Диаграмма размаха времени, проведённого на сайте', fontsize=15)
plt.xlabel('Минуты')
plt.show()

# %%
market_time['минут'].plot(kind = 'hist', bins = 20, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения времени, проведённого на сайте', fontsize=15)
plt.xlabel('Минуты')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %% [markdown]
# Категориальные признаки market_time:

# %%
mt = market_time.copy()
ax = mt['период'].value_counts(ascending=True).plot(
    kind='barh',
    figsize=(10, 2),
    title='Период, во время которого зафиксировано общее время, которое покупатель провёл на сайте')

for p in ax.patches:
    width = p.get_width()
    ax.annotate(f'{width}',
                (width, p.get_y() + p.get_height() / 2.),
                ha='left', va='center',
                xytext=(5, 0),
                textcoords='offset points')

plt.xlabel('Количество клиентов')
plt.ylabel('Период')
plt.show()

# %% [markdown]
# Количественные признаки money:

# %%
money.head()
# Out:
#        id  прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
money['прибыль'].describe()
# Out:
# count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='прибыль',data=money)
plt.title('Диаграмма размаха прибыли продавца за последние 3 месяца от продаж каждому покупателю', fontsize=15)
plt.xlabel('Прибыль')
plt.show()

# %%
money['прибыль'].plot(kind = 'hist', bins = 20, figsize = (20, 5), grid = True, legend = True)
plt.title('Гистограмма распределения прибыли продавца за последние 3 месяца  от продаж каждому покупателю', fontsize=15)
plt.xlabel('Прибыль')
plt.ylabel('Кол-во клиентов')
plt.grid(True)
plt.show()

# %% [markdown]
# Отберем клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.

# %%
market_money = market_money.groupby('id').filter(lambda x: (x['период'].nunique() == 3) & (x['выручка'].min() > 0))

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3888 entries, 3 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3888 non-null   int64
#  1   период   3888 non-null   object
#  2   выручка  3888 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 121.5+ KB

# %% [markdown]
# <font color='Black'><b>Вывод после исследовательского анализа данных:  </b></font><br>
#
# - В среднем за последние 6 месяцев на каждого клиента приходилось 4 маркетинговых коммуникаций компании на покупателя.
# - У клиентов, на которых приходилось меньше 3 маркетинговых коммуникаций за последние 6 месяцев, снизилась покупательская активность.
# - В среднем в текущем месяце на каждого клиента приходилось 4 маркетинговых коммуникаций компании на покупателя , на всех клиентов приходилось от 3 до 5 маркетинговых коммуникаций.
# - По гистограмме распределения времени с момента регистрации покупателя на сайте видим, что регистрации на сайте идут на убыль
# - У клиентов, которые совершают покупки по акции, снизилась покупательская активность.
# - Среднее количество просмотра категорий за визит: 3 категории.
# - У клиентов, имеющие более 5 неоплаченных товаров в корзине за последние 3 месяца, снизилась покупательская активность.
# - В среднем происходит 4 сбоя во время посещения сайта.
# - В среднем за последние 3 месяца покупатель за один визит на сайт просматривает 5-11 страниц.
# - Покупательская активность снизилась у 38% клиентов.
# - Около 30% клиентов используют премиум сервис.
# - 74% клиентов разрешают отправлять доп. предложения о товаре.
# - Самые популярные категории товаров по убыванию: товары для детей, дом. текстиль, косметика и аксессуары, техника для красоты и здоровья, мелкая бытовая техника, посуда.
# - Сумма выручки, которую получает магазин с покупателя за период взаимодействия с сайтом, составляет от 3 тыс. до 7 тыс. (с пиковым значением 5 тыс.)
# - Выручка за текущий месяц составила 6,8 млн., в прошлом месяце 6,4 млн., в позапрошлом 6,25 млн. То есть выручка с каждым месяцем растет.
# - На сайте клиент проводит от 10 до 16 минут.

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# Данные о выручке и времени на сайте находятся в одном столбце для всех периодов. Перед объединением сделаем отдельный столбец для каждого периода.

# %%
market_money['выручка_текущий_месяц'] = market_money.loc[market_money['период'] == 'текущий_месяц', 'выручка']
market_money['выручка_предыдущий_месяц'] = market_money.loc[market_money['период'] == 'предыдущий_месяц', 'выручка']   
market_money['выручка_препредыдущий_месяц'] = market_money.loc[market_money['период'] == 'препредыдущий_месяц', 'выручка']   
drop_columns=['период', 'выручка']
market_money= market_money.drop(drop_columns, axis =1)

# %%
market_money = market_money.groupby('id').agg({'выручка_текущий_месяц':'first', 'выручка_предыдущий_месяц':'first',
                                                 'выручка_препредыдущий_месяц':'first' })
market_money.head()
# Out:
#         выручка_текущий_месяц  выручка_предыдущий_месяц  \
# id
# 215349                 4971.6                    5216.0
# 215350                 5058.4                    5457.5
# 215351                 6610.4                    6158.0
# 215352                 5872.5                    5807.5
# 215353                 5388.5                    4738.5
#
#         выручка_препредыдущий_месяц
# id
# 215349                       4472.0
# 215350                       4826.0
# 215351                       4793.0
# 215352                       4594.0
# 215353                       5124.0

# %%
market_time['период_текущий_месяц'] = market_time.loc[market_time['период'] == 'текущий_месяц', 'минут']
market_time['период_предыдущий_месяц'] = market_time.loc[market_time['период'] == 'предыдущий_месяц', 'минут']
drop_columns=['период', 'минут']
market_time= market_time.drop(drop_columns, axis =1)

# %%
market_time = market_time.groupby('id').agg({'период_текущий_месяц':'first', 'период_предыдущий_месяц':'first'})
market_time.head()
# Out:
#         период_текущий_месяц  период_предыдущий_месяц
# id
# 215348                  14.0                     13.0
# 215349                  10.0                     12.0
# 215350                  13.0                      8.0
# 215351                  13.0                     11.0
# 215352                  11.0                      8.0

# %%
data = pd.merge(pd.merge(market_file, market_money, on='id'), market_time, on='id')
data
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1291  216643           Прежний уровень    стандарт                 да
# 1292  216644           Прежний уровень    стандарт                нет
# 1293  216645           Прежний уровень    стандарт                 да
# 1294  216646           Прежний уровень    стандарт                 да
# 1295  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %% [markdown]
# ## Корреляционный анализ

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(data.corr(method='spearman'), annot=True, cmap='coolwarm')
plt.title('Тепловая карта корреляции')
plt.show()

# %%
phik_matrix = data.phik_matrix()
plt.figure(figsize=(20, 20))
sns.heatmap(phik_matrix, annot=True, cmap='coolwarm')
plt.title('Тепловая карта корреляции')
plt.show()
# Out:
# interval columns not set, guessing: ['id', 'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'выручка_текущий_месяц', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'период_текущий_месяц', 'период_предыдущий_месяц']

# %% [markdown]
# У целевого признака покупательская активность есть корреляция с данными:
# - количество страниц, которые просмотрел покупатель за один визит на сайт;
# - время, которое покупатель провёл на сайте.
#
# В остальном корреляция между признаками слабая. Линейная модель не подойдет.

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# Применим все изученные модели. Для этого используем пайплайны.

# %% [markdown]
# 6.1 Во время подготовки данных используем ColumnTransformer. Количественные и категориальные признаки обработаем в пайплайне раздельно. Для кодирования категориальных признаков используем как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.

# %%
RANDOM_STATE=42
TEST_SIZE=0.25

X = data.drop(['покупательская_активность', 'id'], axis=1)
y = data['покупательская_активность']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = TEST_SIZE, random_state = RANDOM_STATE, stratify = y)

# %%
ohe_columns = ['популярная_категория']
ord_columns = ['тип_сервиса', 'разрешить_сообщать']

num_columns = ['маркет_актив_6_мес', 
               'маркет_актив_тек_мес', 
               'длительность', 
               'акционные_покупки', 
               'средний_просмотр_категорий_за_визит', 
               'неоплаченные_продукты_штук_квартал', 
               'ошибка_сервиса', 
               'страниц_за_визит', 
               'выручка_текущий_месяц', 
               'выручка_предыдущий_месяц', 
               'выручка_препредыдущий_месяц', 
               'период_текущий_месяц', 
               'период_предыдущий_месяц']

# %%
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(handle_unknown='error', sparse_output=False)
        )
    ]
)

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'], 
                    ['да', 'нет'],
                ], 
                handle_unknown='use_encoded_value' , unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# 6.2 Обучите четыре модели: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC(). Для каждой из них подберите как минимум один гиперпараметр. Выберите подходящую для задачи метрику, аргументируйте свой выбор. Используйте эту метрику при подборе гиперпараметров.

# %%
pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, kernel='poly', probability = True)],
        'models__degree': range(2, 3),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %% [markdown]
# Выберем метрику roc-auc т.к. это всеохватывающая метрика качества классификации. Она оценивает качество решений модели в наиболее общем виде, учитывая все возможные пороговые значения.

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=10,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %%
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(sparse_output=False))]),
#                                                                                ['популярная_категория']),
#                                                                               ('ord',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели по кросс валидацинной выборке:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(sparse_output=False))]),
#                                                   ['популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ord',
# ...

# %%
y_test_pred = randomized_search.predict(X_test)
y_test_proba = randomized_search.predict_proba(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test, y_test_proba[:,1]), 2)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.92

# %% [markdown]
# <font color='Black'><b>Вывод после использования пайплайнов для поиска лучшей модели:  </b></font><br>
#
# - Лучше всего справилась модель LogisticRegression с параметрами (C=4, penalty='l1', random_state=42, solver='liblinear')
#
#     - C=4 — значение параметра, который действует как обратная величина силы регуляризации. Меньшие значения указывают на более сильную регуляризацию.
#
#     - Penalty='l1' — параметр лассо-регуляризации, который позволяет упростить модель, установив некоторые веса признаков на ноль и удалив их из модели.
#
#     - Random_state=42 — константа, которая используется для перемешивания данных.
#
#     - Solver='liblinear' — один из алгоритмов оптимизации, реализованных в библиотеке scikit-learn. Обычно используется для задач двоичной классификации и хорошо работает на средних и больших наборах данных.
#
#     - Метрика ROC-AUC = 0.92, что является хорошим результатом.

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# 7.1 Оценим важность признаков для лучшей модели и построим график важности с помощью метода SHAP.

# %%
X_combined = pd.concat([X_train, X_test])
y_combined = pd.concat([y_train, y_test])

# %%
y_combined_pred = randomized_search.predict(X_combined)
pred_df = pd.DataFrame(y_combined_pred, columns=["прогноз"])

# %%
y_combined_prob = randomized_search.predict_proba(X_combined)[:, 1]
prob_df = pd.DataFrame(y_combined_prob, columns=["вероятность_снижения"])

# %%
randomized_search.classes_
# Out:
# array(['Прежний уровень', 'Снизилась'], dtype=object)

# %% [markdown]
# Если model.classes_ = ['Прежний уровень', 'Снизилась'], то:
#
# - predict_proba(X)[:, 0] → P('Прежний уровень')
# - predict_proba(X)[:, 1] → P('Снизилась')

# %%
data['прогноз'] = pred_df
data['вероятность_снижения'] = prob_df
data.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
X_train_2 = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
X_test_2 = pipe_final.named_steps['preprocessor'].transform(X_test)

try:
    feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()
except AttributeError:
    feature_names = [f"feature_{i}" for i in range(X_test_2.shape[1])]

X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)

# %%
explainer = shap.LinearExplainer(randomized_search.best_estimator_.named_steps['models'], X_train_2)
shap_values = explainer(X_test_2)

# %%
#shap.plots.beeswarm(shap_values, max_display=15)

shap.summary_plot(
    shap_values, 
    X_test_2, 
    plot_type="dot", 
    max_display=15,
    plot_size=(18, 6))

# %% [markdown]
# Что смотрим:
#
# - Порядок признаков — признаки отсортированы по важности (сверху самые влиятельные).
#
# - Распределение точек:
#
#     - Цвет (красный → высокие значения признака, синий → низкие) показывает, как значение признака влияет на выход модели.
#
#     - Разброс точек по горизонтали — насколько сильно признак влияет на предсказание.

# %% [markdown]
# - Высокие акционные покупки приводят к увеличению вероятности "снизилось"
# - Высокое кол-во неоплаченных товаров в корзине приводят к увеличению вероятности "снизилось"
# - Высокое кол-во страниц, которые просмотрел покупатель за один визит приводят к увеличению вероятности "прежний уровень"
# - Популярная категория мелкая бытовая техника и электроника приводят к увеличению вероятности "прежний уровень"

# %% [markdown]
# Смотрим далее:
#
# Диаграмма shap.plots.waterfall визуализирует индивидуальные SHAP-значения каждого наблюдения в датасете. Вот как будет выглядеть график для шестого объекта:

# %%
shap.plots.waterfall(shap_values[5])

# %% [markdown]
# Сильнее всего на классификацию влияет признак "Средний просмотр категорий за визит": он «перетягивает» предсказание в сторону класса 0. Значение f(x) на графике показывает, к какому классу признак склоняет наблюдение: отрицательные значения говорят о том, что наблюдение скорее относится к классу 0, а положительные — к классу 1.

# %%
shap.summary_plot(shap_values, plot_type="bar", max_display=20, show=False, plot_size=(18, 6))
plt.title('График общей значимости признаков', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# Самыми важными признаками для построения модели были:
# - кол-во страниц за визит;
# - среднее кол-во просмотренных категорий за визит;
# - проведенное в предыдущем месяце время;
# - проведенное в текущем месяце время;
# - доля акционных покупок.
#
# Наименее важные признаки:
# - тип сервиса;
# - количество маркетинговых коммуникаций в текущем месяце;
# - разрешение на отправку рекламынх рассылок;
# - сколько дней прошло с момента регистрации покупателя на сайте;
# - популярная категория товаров у покупателя (исключение бытовая техника и техника для красоты).

# %% [markdown]
# Построим матрицу ошибок:

# %%
cm = confusion_matrix(y_test, y_test_pred)
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['Прежний уровень', 'Снизилась']  
)
disp.plot(cmap='Blues', values_format='d')
plt.show()

# %% [markdown]
# Итого:
# - модель 7 раз ошибочно предсказывает, что покупательская активность снизилась;
# - модель 22 раза ошибочно предсказывает, что покупательская активность осталась на прежнем уровне.

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# 8.1 Сегментация покупателей.
#
# Используя данные модели и данные о прибыльности клиентов, нужно выделить сегмент покупателей и разработать для них персонализированные предложения.
#
# Выберу сегменты:
# 1. Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# 2. Группа клиентов, которые покупают товары из категории «Товары для детей».
#
#
# - Высокой вероятностью снижения покупательской активности будем считать > 0.65
# - Высокую долю покупок по акции > 0.5

# %%
data = data.merge(money, on='id', how='inner') # id, которые есть в обоих датафреймах

# %%
segmentation_1 = data.loc[(data['вероятность_снижения'] >= 0.65) & (data['акционные_покупки'] >= 0.50)]

# %%
segmentation_1 = data.loc[(data['вероятность_снижения'] >= 0.65) & (data['популярная_категория'] == 'Товары для детей')]

# %% [markdown]
# 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
# - Проведите графическое и аналитическое исследование группы покупателей.
# - Сделайте предложения по работе с сегментом для увеличения покупательской активности.

# %%
data['сегментация_1'] = data.apply( lambda row: 'Исследуемый сегмент' \
        if row['вероятность_снижения'] > 0.65 and row['акционные_покупки'] > 0.50 \
        else 'Остальные пользователи', axis=1)

# %%
data['сегментация_2'] = data.apply( lambda row: 'Исследуемый сегмент' \
        if row['вероятность_снижения'] > 0.65 and row['популярная_категория'] == 'Товары для детей' \
        else 'Остальные пользователи', axis=1)

# %%
data
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1291  216643           Прежний уровень    стандарт                 да
# 1292  216644           Прежний уровень    стандарт                нет
# 1293  216645           Прежний уровень    стандарт                 да
# 1294  216646           Прежний уровень    стандарт                 да
# 1295  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %%
def chart_hist_(df, col, target, xlabel_rotation=0):
    sns.set()
    f, axes = plt.subplots(1, 1, figsize=(14, 6))
    axes.set_title(f'Гистограмма для {col}', fontsize=10)
    axes.set_ylabel('Количество', fontsize=12)
    plt.xticks(rotation=xlabel_rotation)  # Установка наклона подписей по оси x
    if target != None:
        sns.histplot(df, bins=25, kde=True, ax=axes, hue=target, x=col)
    else:
        sns.histplot(df, bins=25, kde=True, ax=axes, x=col)
    plt.show()

# %%
# Коммуникация с клиентом:
chart_hist_(data, 'тип_сервиса', 'сегментация_1')
chart_hist_(data, 'разрешить_сообщать', 'сегментация_1')
chart_hist_(data, 'маркет_актив_6_мес', 'сегментация_1')
chart_hist_(data, 'маркет_актив_тек_мес', 'сегментация_1')
chart_hist_(data, 'длительность', 'сегментация_1')

# %%
# Продуктовое поведение:
chart_hist_(data, 'популярная_категория', 'сегментация_1')
chart_hist_(data, 'средний_просмотр_категорий_за_визит', 'сегментация_1')
chart_hist_(data, 'неоплаченные_продукты_штук_квартал', 'сегментация_1')

# %%
# Поведение на сайте
chart_hist_(data, 'ошибка_сервиса', 'сегментация_1')
chart_hist_(data, 'страниц_за_визит', 'сегментация_1')
chart_hist_(data, 'период_текущий_месяц', 'сегментация_1')
chart_hist_(data, 'период_предыдущий_месяц', 'сегментация_1')

# %%
# Финансовое поведение
chart_hist_(data, 'выручка_текущий_месяц', 'сегментация_1')
chart_hist_(data, 'выручка_предыдущий_месяц', 'сегментация_1')
chart_hist_(data, 'выручка_препредыдущий_месяц', 'сегментация_1')

# %% [markdown]
# Относительно небольшой сегмент покупателей. Проверим второй выбранный сегмент.

# %%
# Коммуникация с клиентом:
chart_hist_(data, 'тип_сервиса', 'сегментация_2')
chart_hist_(data, 'разрешить_сообщать', 'сегментация_2')
chart_hist_(data, 'маркет_актив_6_мес', 'сегментация_2')
chart_hist_(data, 'маркет_актив_тек_мес', 'сегментация_2')
chart_hist_(data, 'длительность', 'сегментация_2')

# %%
# Продуктовое поведение:

chart_hist_(data, 'средний_просмотр_категорий_за_визит', 'сегментация_2')
chart_hist_(data, 'неоплаченные_продукты_штук_квартал', 'сегментация_2')

# %%
# Поведение на сайте
chart_hist_(data, 'ошибка_сервиса', 'сегментация_2')
chart_hist_(data, 'страниц_за_визит', 'сегментация_2')
chart_hist_(data, 'период_текущий_месяц', 'сегментация_2')
chart_hist_(data, 'период_предыдущий_месяц', 'сегментация_2')

# %%
# Финансовое поведение
chart_hist_(data, 'выручка_текущий_месяц', 'сегментация_2')
chart_hist_(data, 'выручка_предыдущий_месяц', 'сегментация_2')
chart_hist_(data, 'выручка_препредыдущий_месяц', 'сегментация_2')
chart_hist_(data, 'акционные_покупки', 'сегментация_2')

# %% [markdown]
# 8.3 Выводы о сегментах:

# %% [markdown]
# Для дополнительного исследования были взяты два сегмента клиентов:
# 1. Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# 2. Группа клиентов, которые покупают товары из категории «Товары для детей».
#
# Предложения для бизнеса для сохранения вовлеченности клиента:
# - увеличение среднего количества страниц, которые просмотрел покупатель за один визит на сайт;
# - увеличение количества категорий, которые покупатель просмотрел за визит;
# - увеличение времени, которое покупатель провёл на сайте.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <font color='Black'><b>Цель данной работы:</b></font><br>
# разработать решение, которое позволит персонализировать предложения постоянным клиентам интернет-магазина «В один клик», чтобы увеличить их покупательскую активность.
#
# Первым этапом была выполнена работа по ознакомлению с данными и их предобработке.
#
# Следующим этапом нами был проведен исследовательский анализ данных.
#
# <font color='Black'><b>Вывод после исследовательского анализа данных:  </b></font><br>
# - В среднем за последние 6 месяцев на каждого клиента приходилось 4 маркетинговых коммуникаций компании на покупателя.
# - У клиентов, на которых приходилось меньше 3 маркетинговых коммуникаций за последние 6 месяцев, снизилась покупательская активность.
# - В среднем в текущем месяце на каждого клиента приходилось 4 маркетинговых коммуникаций компании на покупателя , на всех клиентов приходилось от 3 до 5 маркетинговых коммуникаций.
# - По гистограмме распределения времени с момента регистрации покупателя на сайте видим, что регистрации на сайте идут на убыль
# - У клиентов, которые совершают покупки по акции, снизилась покупательская активность.
# - Среднее количество просмотра категорий за визит: 3 категории.
# - У клиентов, имеющие более 5 неоплаченных товаров в корзине за последние 3 месяца, снизилась покупательская активность.
# - В среднем происходит 4 сбоя во время посещения сайта.
# - В среднем за последние 3 месяца покупатель за один визит на сайт просматривает 5-11 страниц.
# - Покупательская активность снизилась у 38% клиентов.
# - Около 30% клиентов используют премиум сервис.
# - 74% клиентов разрешают отправлять доп. предложения о товаре.
# - Самые популярные категории товаров по убыванию: товары для детей, дом. текстиль, косметика и аксессуары, техника для красоты и здоровья, мелкая бытовая техника, посуда.
# - Сумма выручки, которую получает магазин с покупателя за период взаимодействия с сайтом, составляет от 3 тыс. до 7 тыс. (с пиковым значением 5 тыс.)
# - Выручка за текущий месяц составила 6,8 млн., в прошлом месяце 6,4 млн., в позапрошлом 6,25 млн. То есть выручка с каждым месяцем растет.
# - На сайте клиент проводит от 10 до 16 минут.
#
# Затем мы объединили таблицы и провели корреляционный анализ.
#
# <font color='Black'><b>Вывод после корреляционного анализа:  </b></font><br>
# У целевого признака покупательская активность есть корреляция с данными:
# - количество страниц, которые просмотрел покупатель за один визит на сайт;
# - время, которое покупатель провёл на сайте;
# - в остальном корреляция между признаками слабая.
#
#
# После мы подготовили пайплайн для поиска лучшей модели.
#
# <font color='Black'><b>Вывод после использования пайплайнов:  </b></font><br>
# Лучше всего справилась модель LogisticRegression с параметрами (C=4, penalty='l1', random_state=42, solver='liblinear')
# - C=4 — значение параметра, который действует как обратная величина силы регуляризации. Меньшие значения указывают на более сильную регуляризацию.
# - Penalty='l1' — параметр лассо-регуляризации, который позволяет упростить модель, установив некоторые веса признаков на ноль и удалив их из модели.
# - Random_state=42 — константа, которая используется для перемешивания данных.
# - Solver='liblinear' — один из алгоритмов оптимизации, реализованных в библиотеке scikit-learn. Обычно используется для задач двоичной классификации и хорошо работает на средних и больших наборах данных.
# - Метрика ROC-AUC = 0.92, что является хорошим результатом.
#
# Затем мы провели анализ важности признаков. Это было необходимо для того, чтобы понять как работает модель, какие признаки являются более или менее весомыми для принятия решения.
#
# - Самыми важными признаками для построения модели были:
#     - кол-во страниц за визит;
#     - среднее кол-во просмотренных категорий за визит;
#     - проведенное в предыдущем месяце время;
#     - проведенное в текущем месяце время;
#     - доля акционных покупок.
#
# - Наименее важные признаки:
#     - тип сервиса;
#     - количество маркетинговых коммуникаций в текущем месяце;
#     - разрешение на отправку рекламынх рассылок;
#     - сколько дней прошло с момента регистрации покупателя на сайте;
#     - популярная категория товаров у покупателя (исключение бытовая техника и техника для красоты).
#
# На заключительном этапе для дополнительного исследования мы рассмотрели отдельные сегменты клиентов.
# Были взяты два сегмента клиентов:
#
# 1. Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# 2. Группа клиентов, которые покупают товары из категории «Товары для детей».
#
# В итоге было сделано предложение для бизнеса, что именно необходимо для сохранения вовлеченности клиента:
# - увеличение среднего количества страниц, которые просмотрел покупатель за один визит на сайт;
# - увеличение количества категорий, которые покупатель просмотрел за визит;
# - увеличение времени, которое покупатель провёл на сайте.
